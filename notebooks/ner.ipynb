# %% [markdown]
# # NER
#
# ## Initialize
#
# Initilize the Llm inference provider to get the entities from text.

# %%
import sys
import os

sys.path.append(os.path.abspath("../src"))

from llm_ner_nel.inference_api.entity_inference import EntityInferenceProvider, display_entities

# %% [markdown]
# ## Text --> Entities

# %%
text = '''Vincent de Groof is a Dutch-born Belgian early pioneering aeronaut. He created an early model of an ornithopter'''

inference_provider = EntityInferenceProvider(model="llama3.2") 
entities = inference_provider.get_entities(text)

display_entities(entities, console_log=True)
# Out:
# Vincent de Groof-[Person]. (1.0)
# Dutch-[Nationality]. (1.0)

# %% [markdown]
# ### GPT (4o-mini)

# %%
text = '''Vincent de Groof is a Dutch-born Belgian early pioneering aeronaut. He created an early model of an ornithopter'''

inference_provider = EntityInferenceProvider(model="gpt-4o-mini", strategy="openai") 
entities = inference_provider.get_entities(text)

display_entities(entities, console_log=True)
# Out:
# Vincent de Groof-[Person]. (1.0)
# Belgium-[Country]. (1.0)
# Netherlands-[Country]. (0.8)

# %% [markdown]
# ### GPT (5-mini)

# %%
text = '''Vincent de Groof is a Dutch-born Belgian early pioneering aeronaut. He created an early model of an ornithopter'''
inference_provider = EntityInferenceProvider(model="gpt-5-mini", strategy="openai") 
entities = inference_provider.get_entities(text)

display_entities(entities, console_log=True)
# Out:
# Vincent de Groof-[Person]. (1.0)
# Belgium-[Country]. (1.0)
# Netherlands-[Country]. (0.9)
# Ornithopter-[Invention]. (0.95)

# %% [markdown]
# ### GPT (5-nano)

# %%
text = '''Vincent de Groof is a Dutch-born Belgian early pioneering aeronaut. He created an early model of an ornithopter'''
inference_provider = EntityInferenceProvider(model="gpt-5-nano", strategy="openai") 
entities = inference_provider.get_entities(text)

display_entities(entities, console_log=True)
# Out:
# Vincent de Groof-[Person]. (1.0)
# Belgium-[Country]. (0.95)
# The Netherlands-[Country]. (0.95)

# %% [markdown]
# ### GPT (o4-mini)

# %%
text = '''Vincent de Groof is a Dutch-born Belgian early pioneering aeronaut. He created an early model of an ornithopter'''
inference_provider = EntityInferenceProvider(model="o4-mini", strategy="openai") 
entities = inference_provider.get_entities(text)

display_entities(entities, console_log=True)
# Out:
# Vincent de Groof-[Person]. (1.0)
# Netherlands-[Location]. (1.0)
# Belgium-[Location]. (1.0)
# Ornithopter-[Product/Technology]. (1.0)

# %% [markdown]
# ### GPT (oss-20b)

# %%
text = '''Vincent de Groof is a Dutch-born Belgian early pioneering aeronaut. He created an early model of an ornithopter'''
inference_provider = EntityInferenceProvider(model="gpt-oss:20b", strategy="gpt-oss") 
entities = inference_provider.get_entities(text)

display_entities(entities, console_log=True)
# Out:
# Vincent de Groof-[Person]. (1.0)
# Dutch-born Belgian-[Nationality]. (0.8)
# ornithopter-[Technology/Device]. (1.0)

# %%
text = '''Vincent de Groof is a Dutch-born Belgian early pioneering aeronaut. He created an early model of an ornithopter'''
inference_provider = EntityInferenceProvider(model="gemini-2.5-flash", strategy="google") 
entities = inference_provider.get_entities(text)

display_entities(entities, console_log=True)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[2], line 3
#       1 text = '''Vincent de Groof is a Dutch-born Belgian early pioneering aeronaut. He created an early model of an ornithopter'''
#       2 inference_provider = EntityInferenceProvider(model="gemini-2.5-flash", strategy="google")
# ----> 3 entities = inference_provider.get_entities(text)
#       5 display_entities(entities, console_log=True)
#
# File ~/src/LlmKnowledgeGraph/src/llm_ner_nel/inference_api/entity_inference.py:73, in EntityInferenceProvider.get_entities(self, text)
#      70 prompt = self.generate_prompt(cleaned)
#      71 system_prompt = self.generate_system_prompt();
# ---> 73 return self.inference(
#      74     prompt=prompt,
#      75     system=system_prompt)
#
# File ~/src/LlmKnowledgeGraph/src/llm_ner_nel/inference_api/entity_inference.py:54, in EntityInferenceProvider.inference(self, prompt, system)
#      53 def inference(self, prompt: str, system: str) -> Entities:
# ---> 54     return self.inference_strategy.inference(prompt=prompt, system=system, model=self.model, json_response_type=Entities)
#
# File ~/src/LlmKnowledgeGraph/src/llm_ner_nel/inference_api/strategies/google_ai_studio.py:22, in GoogleStrategy.inference(self, prompt, system, model, json_response_type)
#      20 def inference(self, prompt: str, system: str, model: str, json_response_type: Type[T]) -> T:
#      21     if self.cache == None:
# ---> 22         self.cache = self.client.caches.create(
#      23             model=model,
#      24             config=types.CreateCachedContentConfig(
#      25                 display_name='ner',
#      26                 system_instruction=(system),
#      27                 ttl="300s"
#      28             )
#      29         )
#      31     response = self.client.models.generate_content(
#      32         model=model,
#      33         contents=prompt,
#      34         config=types.GenerateContentConfig(cached_content=self.cache.name))
#      37     return json_response_type.model_validate_json(response.text)
#
# File ~/.conda/envs/llama-stack/lib/python3.10/site-packages/google/genai/caches.py:902, in Caches.create(self, model, config)
#     899 request_dict = _common.convert_to_dict(request_dict)
#     900 request_dict = _common.encode_unserializable_types(request_dict)
# --> 902 response = self._api_client.request(
#     903     'post', path, request_dict, http_options
#     904 )
#     906 response_dict = {} if not response.body else json.loads(response.body)
#     908 return_value = types.CachedContent._from_response(
#     909     response=response_dict, kwargs=parameter_model.model_dump()
#     910 )
#
# File ~/.conda/envs/llama-stack/lib/python3.10/site-packages/google/genai/_api_client.py:1388, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1378 def request(
#    1379     self,
#    1380     http_method: str,
#    (...)
#    1383     http_options: Optional[HttpOptionsOrDict] = None,
#    1384 ) -> SdkHttpResponse:
#    1385   http_request = self._build_request(
#    1386       http_method, path, request_dict, http_options
#    1387   )
# -> 1388   response = self._request(http_request, http_options, stream=False)
#    1389   response_body = (
#    1390       response.response_stream[0] if response.response_stream else ''
#    1391   )
#    1392   return SdkHttpResponse(headers=response.headers, body=response_body)
#
# File ~/.conda/envs/llama-stack/lib/python3.10/site-packages/google/genai/_api_client.py:1224, in BaseApiClient._request(self, http_request, http_options, stream)
#    1221     retry = tenacity.Retrying(**retry_kwargs)
#    1222     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1224 return self._retry(self._request_once, http_request, stream)
#
# File ~/.conda/envs/llama-stack/lib/python3.10/site-packages/tenacity/__init__.py:475, in Retrying.__call__(self, fn, *args, **kwargs)
#     473 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     474 while True:
# --> 475     do = self.iter(retry_state=retry_state)
#     476     if isinstance(do, DoAttempt):
#     477         try:
#
# File ~/.conda/envs/llama-stack/lib/python3.10/site-packages/tenacity/__init__.py:376, in BaseRetrying.iter(self, retry_state)
#     374 result = None
#     375 for action in self.iter_state.actions:
# --> 376     result = action(retry_state)
#     377 return result
#
# File ~/.conda/envs/llama-stack/lib/python3.10/site-packages/tenacity/__init__.py:418, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     416 retry_exc = self.retry_error_cls(fut)
#     417 if self.reraise:
# --> 418     raise retry_exc.reraise()
#     419 raise retry_exc from fut.exception()
#
# File ~/.conda/envs/llama-stack/lib/python3.10/site-packages/tenacity/__init__.py:185, in RetryError.reraise(self)
#     183 def reraise(self) -> t.NoReturn:
#     184     if self.last_attempt.failed:
# --> 185         raise self.last_attempt.result()
#     186     raise self
#
# File ~/.conda/envs/llama-stack/lib/python3.10/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     449     raise CancelledError()
#     450 elif self._state == FINISHED:
# --> 451     return self.__get_result()
#     453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~/.conda/envs/llama-stack/lib/python3.10/concurrent/futures/_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# File ~/.conda/envs/llama-stack/lib/python3.10/site-packages/tenacity/__init__.py:478, in Retrying.__call__(self, fn, *args, **kwargs)
#     476 if isinstance(do, DoAttempt):
#     477     try:
# --> 478         result = fn(*args, **kwargs)
#     479     except BaseException:  # noqa: B902
#     480         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~/.conda/envs/llama-stack/lib/python3.10/site-packages/google/genai/_api_client.py:1201, in BaseApiClient._request_once(self, http_request, stream)
#    1193 else:
#    1194   response = self._httpx_client.request(
#    1195       method=http_request.method,
#    1196       url=http_request.url,
#    (...)
#    1199       timeout=http_request.timeout,
#    1200   )
# -> 1201   errors.APIError.raise_for_response(response)
#    1202   return HttpResponse(
#    1203       response.headers, response if stream else [response.text]
#    1204   )
#
# File ~/.conda/envs/llama-stack/lib/python3.10/site-packages/google/genai/errors.py:121, in APIError.raise_for_response(cls, response)
#     118 else:
#     119   response_json = response.body_segments[0].get('error', {})
# --> 121 cls.raise_error(response.status_code, response_json, response)
#
# File ~/.conda/envs/llama-stack/lib/python3.10/site-packages/google/genai/errors.py:146, in APIError.raise_error(cls, status_code, response_json, response)
#     132 """Raises an appropriate APIError subclass based on the status code.
#     133
#     134 Args:
#    (...)
#     143   APIError: For other error status codes.
#     144 """
#     145 if 400 <= status_code < 500:
# --> 146   raise ClientError(status_code, response_json, response)
#     147 elif 500 <= status_code < 600:
#     148   raise ServerError(status_code, response_json, response)
#
# ClientError: 404 Not Found. {'message': '', 'status': 'Not Found'}
