# %%
from LlmKnowledgeGraph.InferenceApi.relationshipInference import RelationshipInferenceProvider, display_relationships
from LlmKnowledgeGraph.KnowledgeGraph.graph import KnowledgeGraph

graph = KnowledgeGraph()

# %%
inference_provider = RelationshipInferenceProvider(model="gemma3:27b") 
text = '''Vincent de Groof (6 December 1830 – 9 July 1874) was a Dutch-born Belgian early pioneering aeronaut. He created an early model of an ornithopter and successfully demonstrated its use before fatally crashing the machine in London, UK.[1]. Trump approved work done by Vincent. '''

relationships = inference_provider.get_relationships(text)
#graph.add_or_merge_relationships(relationships, "https://en.wikipedia.org/wiki/Vincent_de_Groof", "Wikipedia")

# %%
text = '''Vincent de Groof (6 December 1830 – 9 July 1874) was a Dutch-born Belgian early pioneering aeronaut. He created an early model of an ornithopter and successfully demonstrated its use before fatally crashing the machine in London, UK.[1]. Trump approved work done by Vincent. '''

inference_provider = RelationshipInferenceProvider(model="granite4:tiny-h") 
display_relationships(inference_provider.get_relationships(text))
# Out:
# Vincent de Groof
# Vincent de Groof:(0.95) (Person) --[was born on]-> 6 December 1830:(0.94) (Date)
# Vincent de Groof:(0.95) (Person) --[died on]-> 9 July 1874:(0.94) (Date)
# Vincent de Groof:(0.95) (Person) --[was a pioneer in the field of]-> Aeronautics:(0.92) (Field)
# Vincent de Groof:(0.95) (Person) --[created an early model of]-> Ornithopter:(0.93) (Device)
# Vincent de Groof:(0.95) (Person) --[successfully demonstrated the use of his ornithopter before]-> Fatal Crash in London, UK:(0.91) (Event)
# Vincent de Groof's Ornithopter Demonstration:(0.92) (Event) --[included work done by]-> Trump:(0.89) (Person)
# Vincent de Groof's Ornithopter Demonstration:(0.92) (Event) --[was approved by]-> Trump Work Done:(0.9) (Work)

# %%
inference_provider = RelationshipInferenceProvider(model="gemma3:4b") 
display_relationships(inference_provider.get_relationships(text))
# Out:
# Early Aeronautics
# Vincent de Groof:(0.98) (Person) --[created]-> Ornithopter Model:(0.96) (Machine)
# Vincent de Groof:(0.98) (Person) --[demonstrated]-> Ornithopter Use:(0.94) (Activity)
# Vincent de Groof:(0.98) (Person) --[fatally crashed]-> Ornithopter Machine:(0.96) (Machine)
# Ornithopter Machine:(0.95) (Machine) --[located in]-> London, UK:(0.93) (Location)
# Trump:(0.88) (Person) --[approved]-> Work done by Vincent:(0.89) (Activity)

# %%
inference_provider = RelationshipInferenceProvider(model="gemma3:12b") 
display_relationships(inference_provider.get_relationships(text))
# Out:
# Aeronautics
# Vincent de Groof:(0.97) (Person) --[was]-> Dutch-born Belgian Aeronaut:(0.96) (Occupation)
# Vincent de Groof:(0.97) (Person) --[created]-> Ornithopter Model:(0.94) (Machine)
# Vincent de Groof:(0.97) (Person) --[crashed]-> Machine:(0.93) (Machine)
# Trump:(0.98) (Person) --[approved]-> Work done by Vincent:(0.92) (Work)

# %%
text = """maria miller, 50, member of parliament for basingstoke and former minister for the disabled . this is how she was described when catapulted into the cabinet as secretary of state for culture, media and sport in september 2012; it's the kind of detail you need to give when writing about someone your readers have never heard .but she had ticked several boxes for david cameron back then: elected in 2005, so no apparent baggage; a professional background (in advertising and pr) rather than a political wonk in the miliband/osborne mould; pugnacious; and the biggest tick of all, she was a woman . although it was of no particular interest that she had no background in culture or sport .will she be missed? er, not really, either in or out of dcms . although she has kept the damage to subsidy to a minimum after the depredations of her predecessor, it has been noted that throughout the whole of derry-londonderry's year as the first uk city of culture in 2013, the culture secretary couldn't find the time to visit the city once . she was attacked in the press for underperforming – and in the daily mail quentin letts found her convicted of the worst of political crimes, that of being boring .she needed to come up with something, not only for herself but for her department . when the coalition government came in, no one gave much chance of dcms surviving at all, and it was saved by the olympics . not only did the games go well, the cultural olympiad, taken by the scruff of the neck by tony hall and ruth mackenzie, was acclaimed by a delighted public and by artists suddenly in demand .a year later, however, the point of dcms was once again being questioned, and miller came up with a stroke of near genius . the story goes that, sitting uneasily in cabinet, she had asked what was being done officially to mark the centenary of the first world war, and was met with awkward glances at the stuccoed ceiling and the blank defence secretary .she decided to take it on, held a hasty press conference at which she was flanked, rather bizarrely, by the communities secretary eric pickles, and announced that the great war would be commemorated, not celebrated, through art . she took £10m from the lottery funds of the arts council and the heritage lottery fund, appointed one of the project directors of the london 2012 festival to put a programme together, and left it to the experts to double the money and commission the art .the result has been a programme, announced a couple of weeks ago, stretching across four years that is both inspiring and sensitive, aimed at ignoring the politics of the whole thing but grasping the human impacts .and, after a plea last year for evidence to show what culture contributes to the economy, she has also been able to take the arts' earning power to the treasury and avoid the further cuts many were expecting in the budget last month . the data was all in the public domain, but she saw it as important to be seen and heard asking, showing at last a respect for the artocracy .more impressively, she has listened to her culture minister, ed vaizey, who has tax breaks for the arts close to his heart and who has also weathered the hunt winter . he also got the kind of rebates the government gives to film production offered to theatre production, though the complexities of the scheme are still being deciphered by arts council england .but, unlike in the golden days of chris smith, secretaries of state for culture, media and sport are not appointed for their love of the arts . miller wasn't, nor will her successor be . and so she won't be missed, but what she has done that her predecessor was unable to do was to keep her hands off and let the cultural sector get on with it – an attitude we all hope her successor will follow .join our community of arts, culture and creative professionals by signing up free to the guardian culture pros network"""

# %%
inference_provider = RelationshipInferenceProvider(model="gemma3:4b") 
display_relationships(inference_provider.get_relationships(text))
# Out:
# Culture and Media in the UK
# Maria Miller:(0.98) (Person) --[served as]-> Secretary of State for Culture, Media and Sport:(0.96) (Government Role)
# Maria Miller:(0.98) (Person) --[employed by]-> Coalition Government:(0.96) (Government)
# Maria Miller:(0.98) (Person) --[saved]-> Department for Culture, Media and Sport (DCMS):(0.96) (Government Department)
# Maria Miller:(0.98) (Person) --[supported]-> Cultural Olympiad:(0.96) (Event)
# Maria Miller:(0.98) (Person) --[utilized]-> Lottery Funds:(0.96) (Funding Source)
# Maria Miller:(0.98) (Person) --[worked with]-> Ed Vaizey:(0.96) (Person)
# Maria Miller:(0.98) (Person) --[influenced]-> Arts Council England:(0.96) (Organization)

# %%
inference_provider = RelationshipInferenceProvider(model="granite4:tiny-h") 
display_relationships(inference_provider.get_relationships(text))

# %%
text = """rolls-royce has pledged to protect 7,000 engineering jobs in the east midlands as part of a £150m investment, 
its largest single outlay in the uk for more than a decade .the engineering firm struck a deal with trade unions that will safeguard work for nearly a third of its 22,300-strong uk workforce for five years, 
as it prepares to double the number of engines it builds .rolls-royce will ditch plans to close a precision machining facility in derby, saving 150 jobs that were at risk, 
as well as creating 200 new positions by building a new testing facility for jet engines .sign up for the business today newsletter: our free financial news emailread moreof the £150m planned investment, 
£90m will be spent on building the “testbed”, rolls-royce’s sixth in derby, where it puts engines destined for commercial jets through their paces .
the testbed will be large enough for rolls-royce’s new range of ultrafan engines, which are bigger and designed to be more fuel efficient than previous models .
it will also use the site to test the trent 900, which powers the airbus a380 “superjumbo”; the trent 1000, used on boeing’s “dreamliner”; 
and the trent xwb, which powers the airbus a350 and has become the world’s fastest-selling engine .the overall plan also includes investment in rolls-royce’s large engine maintenance, 
repair and overhaul facility, as well as the hucknall and annesley sites in nottinghamshire .the trade union unite, which had been campaigning for extra investment from rolls-royce, 
said the plan “effectively secures the manufacturing base of roll-royce in the uk for the next 20 years, along with 7,000 high-quality jobs” .the unite general secretary, 
len mccluskey, said: “this is great news for a world-beating workforce making world-class engines and testament to the hard work of unite’s shop stewards and members 
“it is a good day for british manufacturing that must not be undone by a botched brexit .“the government must now play its part by pursuing a ‘jobs first’ brexit and securing tariff-free access 
to the single market and customs union . a failure to do so risks future investment and decent high quality manufacturing jobs .
”rolls-royce’s commitment to protecting uk jobs comes just four months after it reported a £4 .6bn pre-tax loss, the largest in its history, due to the impact of brexit on sterling and the cost of settling 
corruption charges .the business secretary, greg clark, said the investment “underpins the critical role the uk plays within the global aerospace sector” .“the uk and rolls-royce are 
known throughout the world as pioneers of advanced engineering technology,” he added """



inference_provider = RelationshipInferenceProvider(model="gemma3:4b") 
display_relationships(inference_provider.get_relationships(text))
# Out:
# Rolls-Royce Investment in UK Manufacturing
# Rolls-Royce:(0.95) (Company) --[pledged to protect]-> Engineering Jobs:(0.96) (Job Category)
# Rolls-Royce:(0.95) (Company) --[invested]-> £150m Investment:(0.96) (Financial Investment)
# £150m Investment:(0.96) (Financial Investment) --[allocated to]-> UK Manufacturing:(0.97) (Industry Sector)
# UK Manufacturing:(0.97) (Industry Sector) --[includes]-> Engine Building:(0.99) (Activity)
# Rolls-Royce:(0.95) (Company) --[ditching plans to close]-> Precision Machining Facility:(0.96) (Facility)
# Precision Machining Facility:(0.96) (Facility) --[located in]-> Derby:(0.97) (City)
# Rolls-Royce:(0.95) (Company) --[creating]-> New Positions:(0.96) (Job Category)
# New Positions:(0.96) (Job Category) --[number]-> 200:(0.97) (Quantity)
# Rolls-Royce:(0.95) (Company) --[building]-> Testing Facility:(0.96) (Facility)
# Testing Facility:(0.96) (Facility) --[for]-> Jet Engines:(0.97) (Product)
# Rolls-Royce:(0.95) (Company) --[uses]-> Engine Range:(0.96) (Product)
# Engine Range:(0.96) (Product) --[includes]-> Trent 900:(0.97) (Engine Model)
# Trent 900:(0.97) (Engine Model) --[powers]-> Airbus A380 Superjumbo:(0.99) (Aircraft Model)
# Rolls-Royce:(0.95) (Company) --[uses]-> Trent 1000:(0.96) (Engine Model)
# Trent 1000:(0.97) (Engine Model) --[used on]-> Boeing Dreamliner:(0.99) (Aircraft Model)
# Rolls-Royce:(0.95) (Company) --[uses]-> Trent XWB:(0.96) (Engine Model)
# Trent XWB:(0.97) (Engine Model) --[powers]-> Airbus A350:(0.99) (Aircraft Model)
# Rolls-Royce:(0.95) (Company) --[investing in]-> Large Engine Maintenance Facility:(0.96) (Facility)
# Large Engine Maintenance Facility:(0.96) (Facility) --[located in]-> Derby:(0.97) (City)
# Rolls-Royce:(0.95) (Company) --[committed to]-> Protecting UK Jobs:(0.96) (Action)
# UK Manufacturing:(0.97) (Industry Sector) --[underpins]-> Critical Role:(0.99) (Role)
# Greg Clark:(0.98) (Person) --[said]-> Investment:(0.99) (Financial Investment)
# UK and Rolls-Royce:(0.99) (Entity) --[known throughout the world as]-> Pioneers:(0.99) (Descriptor)
# Advanced Engineering Technology:(0.99) (Descriptor) --[are]-> Pioneers:(0.99) (Descriptor)

# %%
inference_provider = RelationshipInferenceProvider(model="gemma3:12b") 
display_relationships(inference_provider.get_relationships(text))
# Out:
# Rolls-Royce Investment and Job Security
# Rolls-Royce:(0.95) (Organization) --[pledges to protect]-> 7,000 Engineering Jobs:(0.9) (Job)
# Rolls-Royce:(0.95) (Organization) --[makes]-> £150m Investment:(0.92) (Money)
# £150m Investment:(0.92) (Money) --[is]-> Largest Single Outlay:(0.91) (Money)
# Rolls-Royce:(0.95) (Organization) --[strikes deal with]-> Trade Unions:(0.93) (Organization)
# Trade Unions:(0.93) (Organization) --[safeguards work for]-> Nearly a Third of UK Workforce:(0.89) (Group)
# Nearly a Third of UK Workforce:(0.89) (Group) --[is]-> 22,300-strong UK Workforce:(0.91) (Group)
# Rolls-Royce:(0.95) (Organization) --[ditch plans to close]-> Precision Machining Facility:(0.92) (Facility)
# Precision Machining Facility:(0.92) (Facility) --[located in]-> Derby:(0.93) (Location)
# Rolls-Royce:(0.95) (Organization) --[creates]-> 200 New Positions:(0.9) (Job)
# 200 New Positions:(0.9) (Job) --[related to]-> New Testing Facility:(0.92) (Facility)
# £150m Planned Investment:(0.92) (Money) --[includes]-> £90m:(0.93) (Money)
# £90m:(0.93) (Money) --[is for]-> Testbed:(0.92) (Facility)
# Testbed:(0.92) (Facility) --[is]-> Sixth in Derby:(0.93) (Location)
# Testbed:(0.92) (Facility) --[tests]-> Ultrafan Engines:(0.91) (Engine)
# Trent 900:(0.91) (Engine) --[powers]-> Airbus A380:(0.92) (Aircraft)
# Trent 1000:(0.91) (Engine) --[used on]-> Boeing Dreamliner:(0.92) (Aircraft)
# Trent XWB:(0.91) (Engine) --[powers]-> Airbus A350:(0.92) (Aircraft)
# Unite:(0.93) (Organization) --[campaigning for]-> Extra Investment:(0.91) (Money)
# Len McCluskey:(0.92) (Person) --[is]-> General Secretary:(0.93) (Job)
# Rolls-Royce:(0.95) (Organization) --[reported]-> £4.6bn Pre-tax Loss:(0.91) (Money)
# Greg Clark:(0.92) (Person) --[is]-> Business Secretary:(0.93) (Job)

# %%
inference_provider = RelationshipInferenceProvider(model="granite4:tiny-h") 
display_relationships(inference_provider.get_relationships(text))
# Out:
# Rolls-Royce Engineering Jobs Investment
# Rolls-Royce:(0.95) (Organization) --[pledges to protect]-> 7,000 Engineering Jobs in East Midlands:(0.94) (Event)
# Rolls-Royce Investment:(0.93) (Event) --[includes £150m outlay]-> $90M Building Testbed:(0.92) (Financial Amount)
# £150 Million Investment:(0.93) (Event) --[largest single outlay in UK for over a decade]-> $90M Building Testbed:(0.92) (Financial Amount)
# Trade Unions Deal with Rolls-Royce:(0.94) (Event) --[struck a deal to safeguard work for nearly a third of its UK workforce]-> $150M Investment:(0.92) (Financial Amount)
# Rolls-Royce's Commitment to Protect UK Jobs:(0.94) (Event) --[comes just four months after reported £4.6bn pre-tax loss due to Brexit impact and corruption charges]-> $150M Investment:(0.92) (Financial Amount)
# £90 Million Testbed Spending:(0.93) (Event) --[$90M to be spent on building the testbed]-> Rolls-Royce's Sixth Testbed in Derby for Jet Engine Testing:(0.91) (Event)
# $90M Building Rolls-Royce’s Sixth Testbed (Testbed):(0.93) (Event) --[large enough for rolls-royce's new range of ultrafan engines]-> $150M Investment (overall plan):(0.9) (Financial Amount)
# Rolls-Royce's Ultrafan Engines Development Plan:(0.94) (Event) --[$90M to test the ultrafan engines]-> $150M Investment (overall plan):(0.9) (Financial Amount)
# Trent 900 Engine Testing for Airbus A380 Superjumbo:(0.93) (Event) --[$90M to test the trent 900 engine]-> $150M Investment (overall plan):(0.9) (Financial Amount)
# Trent 1000 Engine Testing for Boeing Dreamliner:(0.93) (Event) --[$90M to test the trent 1000 engine]-> $150M Investment (overall plan):(0.9) (Financial Amount)
# Trent XWB Engine Testing for Airbus A350:(0.93) (Event) --[$90M to test the trent xwb engine]-> $150M Investment (overall plan):(0.9) (Financial Amount)
# Rolls-Royce's Large Engine Maintenance, Repair and Overhaul Facility Expansion in Derby:(0.94) (Event) --[$150M Investment (overall plan)]-> $90M Building Testbed:(0.89) (Financial Amount)
# Rolls-Royce's Large Engine Maintenance, Repair and Overhaul Facility Expansion in Hucknall:(0.94) (Event) --[$150M Investment (overall plan)]-> $90M Building Testbed:(0.89) (Financial Amount)
# Rolls-Royce's Large Engine Maintenance, Repair and Overhaul Facility Expansion in Annesley:(0.94) (Event) --[$150M Investment (overall plan)]-> $90M Building Testbed:(0.89) (Financial Amount)
# Trade Union Unite's Campaign for Extra Investment from Rolls-Royce:(0.95) (Event) --[$150M Investment (overall plan)]-> $90M Building Testbed:(0.88) (Financial Amount)
# Len McCluskey, General Secretary of Trade Union Unite:(0.96) (Person) --[$150M Investment (overall plan)]-> Great News for World-Beating Workforce Making World-Class Engines and Testament to Hard Work of Unite's Shop Stewards and Members:(0.9) (Event)
# $150M Investment (Overall Plan):(0.93) (Financial Amount) --[$150M Planned Investment]-> $90M Building Testbed:(0.89) (Event)
# Government Pursuing 'Jobs First' Brexit Policy:(0.94) (Event) --[$150M Investment (overall plan)]-> Securing Tariff-Free Access to Single Market and Customs Union:(0.9) (Event)
# $150M Investment (Overall Plan):(0.93) (Financial Amount) --[$150M Planned Investment]-> Securing Tariff-Free Access to Single Market and Customs Union (Government Pursuing 'Jobs First' Brexit Policy):(0.9) (Event)

# %%
# graph = KnowledgeGraph(model="gpt-oss:20b", device="cuda") # structured output issue

# r = graph.get_relationships(text, "https://en.wikipedia.org/wiki/Vincent_de_Groof", "Wikipedia")
# display_relationships(r)

# %%
text = """
The Trump administration has begun laying off thousands of federal workers in an effort to pressure Democrats amid the ongoing government shutdown.

"The RIFs have begun," White House Office of Management Director Russell Vought announced in a post on X on Friday morning, referring to an acronym for "reductions in force".

A spokesman for his office confirmed the cuts had started and were "substantial". Their size and scope began coming into focus later on Friday, when the administration disclosed seven agencies had started laying off more than 4,000 workers.

President Donald Trump has repeatedly threatened to use the shutdown to further his long-held goal of reducing the federal workforce. 
By law, the federal government must give its workers at least 30-days notice that it is laying them off.

After Vought's tweet, major departments such as Treasury and Health and Human Services (HHS) confirmed they were issuing notices to employees, and Homeland Security, where many of its employees are considered essential, said it would lay off workers at its Cybersecurity and Infrastructure Security Agency.

But exact details were scarce.

Two major unions, the American Federation of Government Employees and AFL-CIO, had filed a lawsuit challenging the legality of Vought's announced plans to carry out layoffs during the shutdown.

On Friday, once he said the process had begun, they asked a federal court in Northern California to temporarily block the move.

"It is disgraceful that the Trump administration has used the government shutdown as an excuse to illegally fire thousands of workers who provide critical services to communities across the country," AFGE president Everett Kelley said.

    What makes this US shutdown different (and more difficult)

In its opposition to the temporary restraining order, lawyers for the OMB revealed which agencies and how many of their employees would be affected first, indicating an estimated 4,600 employees would receive RIF notices starting on Friday.

"The President, through OMB, has determined that agencies should operate more efficiently and has directed them to consider steps to optimize their workforces in light of the ongoing lapse in appropriations," the justice department attorneys argued in the filing.

More than a quarter of the cuts would be made at the Treasury Department, where notices were being sent to approximately 1,446 employees.

HHS was notifying between 1,100 and 1,200 employees, the filing said.

The Department of Education and Department of Housing and Urban Development intended to lay off at least 400 employees apiece, while the Departments of Commerce, Energy, Housing and Urban Development and Homeland Security each planned cuts ranging between 176 to 315 employees, according to the filing.

There was no indication about how many notices the agencies issued on Friday.

The filing also said that 20 to 30 at the Environmental Protection Agency were issued "intent to RIF" notice on Friday, notifying them that they may be affected in the future. Other federal agencies might also make cuts.

A spokesman from the White House budget office told the BBC on Saturday that the layoffs were just the beginning.

"These RIF numbers from the court filing are just a snapshot in time," he said. "More RIFs are coming."

The government lawyers said the labour unions had failed to establish that their members would be irreparably harmed by the layoffs, which is needed for the judge to grant the restraining order. But they said a restraining order would "irreparably harm the government".

A temporary restraining order would prevent agencies "determining how best to organize their workforces", they argued, noting that the government has traditionally been granted the widest latitude in the "dispatch of its own internal affairs".
"""

# %%
inference_provider = RelationshipInferenceProvider(model="gemma3:4b") 
display_relationships(inference_provider.get_relationships(text))
# Out:
# US Government Shutdown and Layoffs
# Trump Administration:(0.95) (Organization) --[initiating]-> Layoffs of Federal Workers:(0.96) (Event)
# Layoffs of Federal Workers:(0.96) (Event) --[result of]-> Government Shutdown:(0.97) (Event)
# Trump Administration:(0.95) (Organization) --[directed]-> Reduction in Force (RIFs):(0.96) (Event)
# Reduction in Force (RIFs):(0.96) (Event) --[implemented by]-> Federal Agencies:(0.97) (Organization)
# Federal Agencies:(0.97) (Organization) --[affected by]-> Layoffs of Federal Workers:(0.96) (Event)
# Trump Administration:(0.95) (Organization) --[challenging]-> Layoffs of Federal Workers:(0.96) (Event)
# American Federation of Government Employees (AFGE):(0.94) (Organization) --[filed lawsuit against]-> Trump Administration:(0.95) (Organization)
# Trump Administration:(0.95) (Organization) --[arguing]-> Restraining Order:(0.96) (Event)
# Restraining Order:(0.96) (Event) --[seeking to prevent]-> Trump Administration:(0.97) (Organization)
# Treasury Department:(0.94) (Organization) --[affected by]-> Layoffs of Federal Workers:(0.95) (Event)
# HHS:(0.94) (Organization) --[affected by]-> Layoffs of Federal Workers:(0.95) (Event)
# Department of Education:(0.94) (Organization) --[affected by]-> Layoffs of Federal Workers:(0.95) (Event)
# Department of Housing and Urban Development:(0.94) (Organization) --[affected by]-> Layoffs of Federal Workers:(0.95) (Event)
# Commerce Department:(0.94) (Organization) --[affected by]-> Layoffs of Federal Workers:(0.95) (Event)
# Energy Department:(0.94) (Organization) --[affected by]-> Layoffs of Federal Workers:(0.95) (Event)
# Homeland Security:(0.94) (Organization) --[affected by]-> Layoffs of Federal Workers:(0.95) (Event)

# %%
inference_provider = RelationshipInferenceProvider(model="granite4:tiny-h") 
display_relationships(inference_provider.get_relationships(text))

# %%
inference_provider = RelationshipInferenceProvider(model="gemma3:12b") 
display_relationships(inference_provider.get_relationships(text))
# Out:
# US Government Shutdown
# Russell Vought:(0.95) (Person) --[announced]-> Layoffs of Federal Workers:(0.94) (Event)
# White House Office of Management:(0.93) (Organization) --[directed]-> Agencies to Optimize Workforces:(0.9) (Organization)
# Donald Trump:(0.97) (Person) --[threatened to use]-> Shutdown:(0.94) (Event)
# Federal Government:(0.96) (Organization) --[must give]-> 30-days Notice:(0.92) (Time)
# Everett Kelley:(0.94) (Person) --[said]-> Layoffs are Disgraceful:(0.93) (Event)
# Department of Treasury:(0.95) (Organization) --[sent notices to]-> 1,446 Employees:(0.92) (Group)
# HHS:(0.96) (Organization) --[notifying]-> 1,100-1,200 Employees:(0.91) (Group)
# Department of Education:(0.94) (Organization) --[intended to lay off]-> 400 Employees:(0.9) (Group)
# Environmental Protection Agency:(0.93) (Organization) --[issued]-> 20-30 Intent to RIF Notice:(0.89) (Event)
